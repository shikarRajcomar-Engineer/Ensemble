# %% [markdown]
# <a href="https://colab.research.google.com/github/shikarRajcomar-Engineer/Ensemble/blob/master/Generic_Kfold_Bloodcell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# %tensorflow_version 1.x
path='/content/drive/My Drive/Blood Cell UKZN/'    
Results=pd.DataFrame([])
Results1=pd.DataFrame([])
Results2=pd.DataFrame([])
Results3=pd.DataFrame([])
Results4=pd.DataFrame([])
Results5=pd.DataFrame([])
Results6=pd.DataFrame([])

aResults=pd.DataFrame([])
aResults1=pd.DataFrame([])
aResults2=pd.DataFrame([])
aResults3=pd.DataFrame([])
aResults4=pd.DataFrame([])
aResults5=pd.DataFrame([])
aResults6=pd.DataFrame([])

bResults=pd.DataFrame([])
bResults1=pd.DataFrame([])
bResults2=pd.DataFrame([])
bResults3=pd.DataFrame([])
bResults4=pd.DataFrame([])
bResults5=pd.DataFrame([])
bResults6=pd.DataFrame([])

cResults=pd.DataFrame([])
cResults1=pd.DataFrame([])
cResults2=pd.DataFrame([])
cResults3=pd.DataFrame([])
cResults4=pd.DataFrame([])
cResults5=pd.DataFrame([])
cResults6=pd.DataFrame([])

dResults=pd.DataFrame([])
dResults1=pd.DataFrame([])
dResults2=pd.DataFrame([])
dResults3=pd.DataFrame([])
dResults4=pd.DataFrame([])
dResults5=pd.DataFrame([])
dResults6=pd.DataFrame([])

eResults=pd.DataFrame([])
eResults1=pd.DataFrame([])
eResults2=pd.DataFrame([])
eResults3=pd.DataFrame([])
eResults4=pd.DataFrame([])
eResults5=pd.DataFrame([])
eResults6=pd.DataFrame([])

fResults=pd.DataFrame([])
fResults1=pd.DataFrame([])
fResults2=pd.DataFrame([])
fResults3=pd.DataFrame([])
fResults4=pd.DataFrame([])
fResults5=pd.DataFrame([])
fResults6=pd.DataFrame([])

gResults=pd.DataFrame([])
gResults1=pd.DataFrame([])
gResults2=pd.DataFrame([])
gResults3=pd.DataFrame([])
gResults4=pd.DataFrame([])
gResults5=pd.DataFrame([])
gResults6=pd.DataFrame([])

hResults=pd.DataFrame([])
hResults1=pd.DataFrame([])
hResults2=pd.DataFrame([])
hResults3=pd.DataFrame([])
hResults4=pd.DataFrame([])
hResults5=pd.DataFrame([])
hResults6=pd.DataFrame([])


Dataset=['SP120','candy120','SPudnie120','SPthe_wave120','SPthe_scream120','SPstarry_night120','SPmosaic120']



batch_size=32
steps=100

# Dataset16=['samplepair224']
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# #Dataset1

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results=Results.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results1=Results1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results2=Results2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results3=Results3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results4=Results4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results5=Results5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results6=Results6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %% [markdown]
# #Dataset2

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults=aResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults1=aResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults2=aResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults3=aResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults4=aResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults5=aResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[1])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[1]),str(Dataset[1]),str(Dataset[1]),str(Dataset[1])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
aResults6=aResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(aResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %% [markdown]
# #Dataset3

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults=bResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults1=bResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults2=bResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults3=bResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults4=bResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults5=bResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[2])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[2]),str(Dataset[2]),str(Dataset[2]),str(Dataset[2])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
bResults6=bResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(bResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
Final=pd.DataFrame([])
Final=Final.append(Results)
Final=Final.append(Results1)
Final=Final.append(Results2)
Final=Final.append(Results3)
Final=Final.append(Results4)
Final=Final.append(Results5)
Final=Final.append(Results6)

Final=Final.append(aResults)
Final=Final.append(aResults1)
Final=Final.append(aResults2)
Final=Final.append(aResults3)
Final=Final.append(aResults4)
Final=Final.append(aResults5)
Final=Final.append(aResults6)

Final=Final.append(bResults)
Final=Final.append(bResults1)
Final=Final.append(bResults2)
Final=Final.append(bResults3)
Final=Final.append(bResults4)
Final=Final.append(bResults5)
Final=Final.append(bResults6)

Final=Final.append(cResults)
Final=Final.append(cResults1)
Final=Final.append(cResults2)
Final=Final.append(cResults3)
Final=Final.append(cResults4)
Final=Final.append(cResults5)
Final=Final.append(cResults6)

Final=Final.append(dResults)
Final=Final.append(dResults1)
Final=Final.append(dResults2)
Final=Final.append(dResults3)
Final=Final.append(dResults4)
Final=Final.append(dResults5)
Final=Final.append(dResults6)

Final=Final.append(eResults)
Final=Final.append(eResults1)
Final=Final.append(eResults2)
Final=Final.append(eResults3)
Final=Final.append(eResults4)
Final=Final.append(eResults5)
Final=Final.append(eResults6)

Final=Final.append(fResults)
Final=Final.append(fResults1)
Final=Final.append(fResults2)
Final=Final.append(fResults3)
Final=Final.append(fResults4)
Final=Final.append(fResults5)
Final=Final.append(fResults6)

Final=Final.append(gResults)
Final=Final.append(gResults1)
Final=Final.append(gResults2)
Final=Final.append(gResults3)
Final=Final.append(gResults4)
Final=Final.append(gResults5)
Final=Final.append(gResults6)



pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Final)
# Out:
#    precision  Precision var    recall  recall var  f1-score  f1-score var  \
# 0   0.152885       0.124830  0.600000    0.489898  0.243678      0.198962
# 1   0.047115       0.094231  0.200000    0.400000  0.076265      0.152529
# 2   0.000000       0.000000  0.000000    0.000000  0.000000      0.000000
# 3   0.051208       0.102415  0.200000    0.400000  0.081538      0.163077
# 0   0.475650       0.180831  0.716981    0.223885  0.558318      0.166081
# 1   0.949540       0.031922  0.583673    0.027683  0.721894      0.013181
# 2   0.618712       0.092300  0.954717    0.034995  0.744920      0.062715
# 3   0.587234       0.480041  0.184906    0.323385  0.211974      0.336602
# 0   0.441792       0.040253  0.784906    0.127187  0.564367      0.065010
# 1   0.882965       0.183887  0.665306    0.158397  0.721024      0.028046
# 2   0.590151       0.127721  0.803774    0.326715  0.660719      0.227305
# 3   0.470000       0.384187  0.052830    0.045283  0.094517      0.080103
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results=Results.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results1=Results1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results2=Results2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results3=Results3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results4=Results4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results4=Results4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results5=Results5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# ...

# %% [markdown]
# #Dataset4

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults=cResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults1=cResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults2=cResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults3=cResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults4=cResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults5=cResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[3])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[3]),str(Dataset[3]),str(Dataset[3]),str(Dataset[3])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
cResults6=cResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(cResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results=Results.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results1=Results1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results2=Results2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results3=Results3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results4=Results4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results4=Results4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[0])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[0]),str(Dataset[0]),str(Dataset[0]),str(Dataset[0])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
Results5=Results5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Results4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %% [markdown]
# #Dataset5

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults=dResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults1=dResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults2=dResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults3=dResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults4=dResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults5=dResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[4])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[4]),str(Dataset[4]),str(Dataset[4]),str(Dataset[4])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
dResults6=dResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(dResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %% [markdown]
# #Dataset6

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults=eResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults1=eResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults2=eResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults3=eResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults4=eResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults5=eResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[5])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[5]),str(Dataset[5]),str(Dataset[5]),str(Dataset[5])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
eResults6=eResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(eResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# ...

# %% [markdown]
# #Dataset7

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from keras.utils import plot_model

# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)
      model.summary()
      plot_model(model, to_file='model.png')
      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(rescale=1./255)
      val_datagen = ImageDataGenerator(rescale=1./255)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['No Aug','No Aug','No Aug','No Aug']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults=fResults.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 120, 120, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 215296)            19392
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               27558016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# ...
# Total params: 27,577,924
# Trainable params: 27,577,924
# Non-trainable params: 0
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(horizontal_flip=True)
      val_datagen = ImageDataGenerator(horizontal_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Hflip','Hflip','Hflip','Hflip']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults1=fResults1.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults1)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, Reshape, LSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import numpy
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])


      
      
      datagen = ImageDataGenerator(vertical_flip=True)
      val_datagen = ImageDataGenerator(vertical_flip=True)

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Vflip','Vflip','Vflip','Vflip']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults2=fResults2.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults2)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))
      val_datagen = ImageDataGenerator(shear_range=(random.randrange(0,100,10)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['shear','shear','shear','shear']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults3=fResults3.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults3)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))
      val_datagen = ImageDataGenerator(rotation_range=(random.randrange(0,360,30)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['rotation','rotation','rotation','rotation']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults4=fResults4.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults4)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(height_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['Height','Height','Height','Height']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults5=fResults5.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults5)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %%
from numpy.random import seed
seed(2)
import tensorflow

import numpy as np 
from os import listdir
from os.path import isfile, join
import cv2
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import sys
import shutil
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import backend as K
import pandas as pd
from sklearn.metrics import classification_report
from numpy.random import seed
from matplotlib import pyplot
from numpy import expand_dims
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve,roc_auc_score
import sklearn
import datetime, os
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.regularizers import l2
import os
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import datetime as datetime
import tensorflow
from skimage import transform as tf
import random
from keras.regularizers import l2
from sklearn.utils import class_weight


# Define Callback function for early stopping and tensorboard
earlystop=EarlyStopping(patience=3)
learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                        ,patience=3
                                        ,verbose=0
                                        ,factor=0.5
                                        ,min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]


# from keras.applications.vgg16 import VGG16
# model = VGG16()


def load_data_training_and_test(datasetname):
        npzfile=np.load(path+datasetname+'training_data.npz')
        train=npzfile['arr_0']
        

        npzfile=np.load(path+datasetname+'training_labels.npz')
        train_labels=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_data.npz')
        test=npzfile['arr_0']

        npzfile=np.load(path+datasetname+'testing_labels.npz')
        test_labels=npzfile['arr_0']    
        return (train,train_labels),(test,test_labels)

(x_train,y_train),(x_test,y_testing)=load_data_training_and_test(Dataset[6])


y_train=y_train.reshape(y_train.shape[0],1)
y_testing=y_testing.reshape(y_testing.shape[0],1)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train/=255
x_test/=255
training_size=len(x_train)
test_size=len(y_testing)
classes = np.unique(y_train)
nClasses = len(classes)
num_classes = len(classes)


kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed())
cvscores = []
cvscores1 = []
precision0=[]
precision1=[]
precision2=[]
precision3=[]
recall0=[]
recall1=[]
recall2=[]
recall3=[]
f1_score0=[]
f1_score1=[]
f1_score2=[]
f1_score3=[]
f11=[]
X = x_train
Y =y_train
for train, test in kfold.split(X, Y):

      input_tensor = Input(shape=x_train.shape[1:])
      modelcnn = Sequential()
      modelcnn.add(Conv2D(32, (3, 3), kernel_initializer=keras.initializers.glorot_uniform(seed=2), kernel_regularizer=l2(0.0001), input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Activation('relu'))

      # modelcnn.add(Conv2D(32, kernel_size=(3, 3),
      #                   activation='relu',
      #                   input_shape=x_train.shape[1:],strides=1))
      modelcnn.add(Conv2D(64, (3, 3), activation='relu'))
      modelcnn.add(MaxPooling2D(pool_size=(2, 2)))
      modelcnn.add(Dropout(0.25))
      modelcnn.add(Flatten())
      cnn_output = modelcnn(input_tensor)

      # Creating RNN    




      # Merging both cnn bottleneck and rnn's output wise element wise multiplication

      last_process = Dense(128, activation='relu')(cnn_output)
      last_process = Dropout(0.5)(last_process)
      output_tensor = Dense(num_classes, activation='softmax')(last_process)
      model = Model(input=input_tensor, output=output_tensor)

      model.compile(optimizer=keras.optimizers.Adadelta(),
              loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])

      
      datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))
      val_datagen = ImageDataGenerator(width_shift_range=(random.uniform(0.1,0.9)))

      earlystop=EarlyStopping(patience=5)
      learning_rate_reduction=ReduceLROnPlateau(monitor='val_accuracy'
                                              ,patience=5
                                              ,verbose=0
                                              ,factor=0.5
                                              ,min_lr=0.00001)

      callbacks = [earlystop, learning_rate_reduction]


      epochs=50

      mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

      train_generator = datagen.flow(X[train],Y[train],batch_size=batch_size)
      validation_generator = val_datagen.flow(X[test],Y[test],batch_size=batch_size)

      history=model.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            verbose=0,
            shuffle=True
            ,callbacks=callbacks)
      
            

      predicted_classes = model.predict(x_test)
      predicted_classes = np.argmax(np.round(predicted_classes),axis=1)


      target_names = ["0","1","2","3"]
      a=classification_report(y_testing, predicted_classes, target_names=target_names,output_dict=True)
      # model.fit(X[train], Y[train], epochs=10, batch_size=32, verbose=0)
      scores = model.evaluate(X[test], Y[test], verbose=0)
      scores1 = model.evaluate(x_test, y_testing, verbose=0)
      cvscores.append(scores[1] * 100)
      cvscores1.append(scores1[1] * 100)
      precision0.append(a['0']['precision'])
      precision1.append(a['1']['precision'])
      precision2.append(a['2']['precision'])
      precision3.append(a['3']['precision'])     
      recall0.append(a['0']['recall'])
      recall1.append(a['1']['recall'])
      recall2.append(a['2']['recall'])
      recall3.append(a['3']['recall'])

      f1_score0.append(a['0']['f1-score'])
      f1_score1.append(a['1']['f1-score'])
      f1_score2.append(a['2']['f1-score'])
      f1_score3.append(a['3']['f1-score'])
df=[numpy.mean(precision0),numpy.mean(precision1),numpy.mean(precision2),numpy.mean(precision3)]
df=pd.DataFrame(df)
df.columns = ['precision']
df['Precision var']=[numpy.std(precision0),numpy.std(precision1),numpy.std(precision2),numpy.std(precision3)]
df['recall']=[numpy.mean(recall0),numpy.mean(recall1),numpy.mean(recall2),numpy.mean(recall3)]
df['recall var']=[numpy.std(recall0),numpy.std(recall1),numpy.std(recall2),numpy.std(recall3)]
df['f1-score']=[numpy.mean(f1_score0),numpy.mean(f1_score1),numpy.mean(f1_score2),numpy.mean(f1_score3)]
df['f1-score var']=[numpy.std(f1_score0),numpy.std(f1_score1),numpy.std(f1_score2),numpy.std(f1_score3)]
df['Accuracy']=[numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores),numpy.mean(cvscores)]
df['Accuracy var']=[numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores),numpy.std(cvscores)]
df['Val Accuracy']=[numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1),numpy.mean(cvscores1)]
df['Val Accuracy var']=[numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1),numpy.std(cvscores1)]
df['aug']=['width','width','width','width']
df['dataset']=[str(Dataset[6]),str(Dataset[6]),str(Dataset[6]),str(Dataset[6])]
df['val acc']=(history.history['val_accuracy'][-1])*100
df['acc']=(history.history['accuracy'][-1])*100
fResults6=fResults6.append(df)
pd.set_option("display.max_rows", None, "display.max_columns", None)
display(fResults6)
keras.backend.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:140: UserWarning:
#
# Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# ...

# %% [markdown]
# # Results

# %%
Final=pd.DataFrame([])
Final=Final.append(Results)
Final=Final.append(Results1)
Final=Final.append(Results2)
Final=Final.append(Results3)
Final=Final.append(Results4)
Final=Final.append(Results5)
Final=Final.append(Results6)

Final=Final.append(aResults)
Final=Final.append(aResults1)
Final=Final.append(aResults2)
Final=Final.append(aResults3)
Final=Final.append(aResults4)
Final=Final.append(aResults5)
Final=Final.append(aResults6)

Final=Final.append(bResults)
Final=Final.append(bResults1)
Final=Final.append(bResults2)
Final=Final.append(bResults3)
Final=Final.append(bResults4)
Final=Final.append(bResults5)
Final=Final.append(bResults6)

Final=Final.append(cResults)
Final=Final.append(cResults1)
Final=Final.append(cResults2)
Final=Final.append(cResults3)
Final=Final.append(cResults4)
Final=Final.append(cResults5)
Final=Final.append(cResults6)

Final=Final.append(dResults)
Final=Final.append(dResults1)
Final=Final.append(dResults2)
Final=Final.append(dResults3)
Final=Final.append(dResults4)
Final=Final.append(dResults5)
Final=Final.append(dResults6)

Final=Final.append(eResults)
Final=Final.append(eResults1)
Final=Final.append(eResults2)
Final=Final.append(eResults3)
Final=Final.append(eResults4)
Final=Final.append(eResults5)
Final=Final.append(eResults6)

Final=Final.append(fResults)
Final=Final.append(fResults1)
Final=Final.append(fResults2)
Final=Final.append(fResults3)
Final=Final.append(fResults4)
Final=Final.append(fResults5)
Final=Final.append(fResults6)

Final=Final.append(gResults)
Final=Final.append(gResults1)
Final=Final.append(gResults2)
Final=Final.append(gResults3)
Final=Final.append(gResults4)
Final=Final.append(gResults5)
Final=Final.append(gResults6)



pd.set_option("display.max_rows", None, "display.max_columns", None)
display(Final)
# Out:
#    precision  Precision var    recall  recall var  f1-score  f1-score var  \
# 0   0.152885       0.124830  0.600000    0.489898  0.243678      0.198962
# 1   0.047115       0.094231  0.200000    0.400000  0.076265      0.152529
# 2   0.000000       0.000000  0.000000    0.000000  0.000000      0.000000
# 3   0.051208       0.102415  0.200000    0.400000  0.081538      0.163077
# 0   0.123352       0.114241  0.456604    0.455558  0.193540      0.182623
# 1   0.045226       0.090452  0.183673    0.367347  0.072581      0.145161
# 2   0.106844       0.131088  0.271698    0.389722  0.144036      0.178794
# 3   0.000000       0.000000  0.000000    0.000000  0.000000      0.000000
# 0   0.203846       0.101923  0.800000    0.400000  0.324904      0.162452
# 1   0.000000       0.000000  0.000000    0.000000  0.000000      0.000000
# 2   0.050962       0.101923  0.200000    0.400000  0.081226      0.162452
# 3   0.000000       0.000000  0.000000    0.000000  0.000000      0.000000
# ...
